# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('/gpfs/home/denesl01/libLTD/GemAnalysis/Clones_full_exp.csv', index_col=0)

# %%
#df_filt = df[df['Deff'] < 3.0]
#df_filt = df_filt[df_filt['Deff'] > 0.0]
df_filt = df.copy()
df_filt = df_filt[df_filt['n_tracks'] < 200]
df_filt = df_filt[df_filt['n_tracks'] > 10]

# %%
for n,item in df_filt.iterrows():
    if item['condition'] == 'P_platingD3':
        f1,f2,f3 = ['P', 'platingD3', ]
    f1,f2,f3 = item['condition'].split('_')
# Out:
# P_platingD3
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 3
#       1 for n,item in df_filt.iterrows():
#       2     print(item['condition'])
# ----> 3     f1,f2,f3 = item['condition'].split('_')
#
# ValueError: not enough values to unpack (expected 3, got 2)

# %%
fig,ax=plt.subplots(figsize=(20,5))
sns.swarmplot(data=df_filt, x='condition', y='Deff', hue='exp', size=3, dodge=True, ax=ax, legend=False)
plt.xticks(rotation=45)
plt.show()
